# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## DATA 690 Practice Session 1

# %%
5+6
# Out:
# 11

# %%
print('Hello world')
# Out:
# Hello world

# %%
a=56
b=65
c=a+b
print ('a+b')
# Out:
# a+b

# %%
a=8
a
# Out:
# 8

# %%
x=5
y=8
if x>5:
    x+=1
y=8

# %%
a=7
type(a)
# Out:
# int

# %%
a="kebab"
type(a)
# Out:
# str

# %%
from datetime import datetime, date, time
dt= datetime(2018, 20, 10 , 15, 30)
dt.day
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8a4649c79a60> in <module>
#       1 from datetime import datetime, date, time
# ----> 2 dt= datetime(2018, 20, 10 , 15, 30)
#       3 dt.day
#
# ValueError: month must be in 1..12

# %%
from datetime import datetime, date, time
dt= datetime(2018, 5, 10 , 15, 30)
dt.day
# Out:
# 10

# %%
ifx<5:
print('It's an integer')
elifx==5:
print('Equal to five')
elif0<x<5:
print('Positive but smaller than 5')
else:
print('Positive and larger than or equal to 5')
# Out:
#   File "<ipython-input-15-e8507f2a9fdb>", line 1
#     ifx<5:
#           ^
# SyntaxError: invalid syntax

# %%
ifa<borc>d print('Made it')
# Out:
#   File "<ipython-input-16-5f140510f6e2>", line 1
#     ifa<borc>d print('Made it')
#                    ^
# SyntaxError: invalid syntax

# %%
a=5
b=7 
c=8
d=4
if a < b or c > d
print('All GOOD')
# Out:
#   File "<ipython-input-20-eb0192ccd848>", line 5
#     if a < b or c > d
#                      ^
# SyntaxError: invalid syntax
